# %%
import pandas as pd

# %%
df = pd.read_csv("small_faq_covid.csv")
df
# Out:
#                                               question  \
# 0                         What is a novel coronavirus?
# 1    Why is the disease being called coronavirus di...
# 2    Why might someone blame or avoid individuals a...
# 3    How can people help stop stigma related to COV...
# 4                     What is the source of the virus?
# ..                                                 ...
# 208  Is water a possible source of infection in the...
# 209  Where can doctors and clinics obtain additiona...
# 210  When was the first information about the outbr...
# 211                    Where did the outbreak start?\n
# 212   Have there been similar outbreaks in the past?\n
#
#                                                 answer  \
# 0    A novel coronavirus is a new coronavirus that ...
# 1    On February 11, 2020 the World Health Organiza...
# 2    People in the U.S. may be worried or anxious a...
# 3    People can fight stigma and help, not hurt, ot...
# ...

# %%
df.fillna("", inplace=True)
df
# Out:
# C:\Users\minhd\AppData\Local\Temp\ipykernel_11756\518953182.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.fillna("", inplace=True)
#                                               question  \
# 0                         What is a novel coronavirus?
# 1    Why is the disease being called coronavirus di...
# 2    Why might someone blame or avoid individuals a...
# 3    How can people help stop stigma related to COV...
# 4                     What is the source of the virus?
# ..                                                 ...
# 208  Is water a possible source of infection in the...
# 209  Where can doctors and clinics obtain additiona...
# 210  When was the first information about the outbr...
# 211                    Where did the outbreak start?\n
# 212   Have there been similar outbreaks in the past?\n
#
# ...

# %%
converted_df = df[['question', 'answer']]
converted_df.columns = ['title', 'content']

# %%
converted_df.to_csv("faq.csv")
converted_df.to_json("faq.json")
